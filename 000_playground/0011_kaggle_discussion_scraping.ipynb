# %% [markdown]
# # Overview
# - beutifulll soup を使ってkaggleのdiscussionを取得することを試みる。
# - 参考: https://github.com/fkubota/arxiv_notification/tree/master/nb

# %% [markdown]
# # Const

# %% [markdown]
# # Import everything I need :)

# %%
import datetime
from bs4 import BeautifulSoup
import requests
from fastprogress import progress_bar

# %% [markdown]
# # Execution

# %%
url = 'https://www.kaggle.com/c/birdsong-recognition/discussion/158933'
response = requests.get(url)
html = response.text

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Cornell Birdcall Identification | Kaggle</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#     <meta name="description" content="Build tools for bird population monitoring" />
#     <meta name="turbolinks-cache-control" content="no-cache" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#     <meta name="theme-color" content="#008ABC" />
#     <script nonce="l5WH1nQs6K7Ywe258yuHVQ==" type="text/javascript">
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.getRegistrations()
#                 .then(function(registrations) {
#                     for (let registration of registrations) {
#                         registration.unregister();
#                     }
#                 })
#                 .catch(function(err) {
# ...

# %% [markdown]
# ---> イミフ
